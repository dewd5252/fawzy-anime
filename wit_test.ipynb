# %%
import wit_anime
from urllib.parse import urlparse

anime_name = "jojo-no-kimyou-na-bouken"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import wit_anime
#       2 from urllib.parse import urlparse
#       4 anime_name = "jojo-no-kimyou-na-bouken"
#
# File d:\anime_scraper-main\anime_scraper-main\wit_anime.py:4
#       2 import base64
#       3 import requests
# ----> 4 from bs4 import BeautifulSoup
#       6 server = "https://witanime.art/"
#       9 def get_soup(url):
#
# ModuleNotFoundError: No module named 'bs4'

# %%
print(wit_anime.latest_episodes())

# %%
print(wit_anime.fetch_seasonals())

# %%
print(wit_anime.search_anime(anime_name))

# %%
print(wit_anime.get_anime_info(anime_name))

# %%
print(wit_anime.get_episodes(anime_name))

# %%
print(wit_anime.get_episode_dl(anime_name)) # will return the first result
